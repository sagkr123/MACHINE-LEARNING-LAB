# %%
import numpy as np
import csv
import math

def read_data(filename):
    with open(filename, 'r') as csvfile:
        datareader = csv.reader(csvfile)
        metadata = next(datareader)
        traindata = [row for row in datareader]
    return metadata, traindata

def splitDataset(dataset, splitRatio):
    trainsize = int(len(dataset) * splitRatio)
    trainset = dataset[:trainsize]
    testset = dataset[trainsize:]
    return trainset, testset

def classify(data, test):
    tol_size = len(data)
    print("\n")
    print("training dataset size", tol_size)
    print("test size", len(test))
    countyes = sum(1 for row in data if row[-1] == 'yes')
    countno = sum(1 for row in data if row[-1] == 'no')
    probyes = countyes / tol_size
    probno = countno / tol_size
    print("\n")
    print("target cannot probability")
    print('yes', "\t", countyes, "\t", probyes)
    print('no', "\t", countno, "\t", probno)
    prob0 = np.zeros((len(test[0]) - 1))
    prob1 = np.zeros((len(test[0]) - 1))
    accuracy = 0
    print("\n")
    print("instance pridiction value")
    for t in range(len(test)):
        for k in range(len(test[0]) - 1):
            count1 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'yes')
            count0 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'no')
            prob0[k] = count0 / countno
            prob1[k] = count1 / countyes
        probno = countno / tol_size
        probyes = countyes / tol_size
        for i in range(len(test[0]) - 1):
            probno = probno * prob0[i]
            probyes = probyes * prob1[i]
        if probno > probyes:
            predict = 'no'
        else:
            predict = 'yes'
        print(t + 1, "\t", predict, "\t", test[t, -1])
        if predict == test[t, -1]:
            accuracy += 1
    final_accuracy = (accuracy / len(test)) * 100
    print("accuracy", final_accuracy, "%")

metadata, traindata = read_data("we.csv")
print("the attribute names of training data:", metadata)
splitRatio = 0.6
trainingset, testset = splitDataset(traindata, splitRatio)
training = np.array(trainingset)
print("\ntraining sets are")
for x in trainingset:
    print(x)
testing = np.array(testset)
print("\nthe datasets are")
for x in testing:
    print(x)
classify(training, testing)
# Out:
# the attribute names of training data: ['weather', 'temperature', 'humidity', 'wind']
#
# training sets are
# ['suuny', 'hot', 'high', 'weak']
#
# the datasets are
# ['suuny' 'hot' 'high' 'strong']
# ['cloudy' 'hot' 'high' 'weak']
#
#
# training dataset size 1
# test size 2
#
#
# target cannot probability
# yes 	 0 	 0.0
# no 	 0 	 0.0
#
#
# instance pridiction value
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 69
#      67 for x in testing:
#      68     print(x)
# ---> 69 classify(training, testing)
#
# Cell In[11], line 40, in classify(data, test)
#      38     count1 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'yes')
#      39     count0 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'no')
# ---> 40     prob0[k] = count0 / countno
#      41     prob1[k] = count1 / countyes
#      42 probno = countno / tol_size
#
# ZeroDivisionError: division by zero

# %%
import numpy as np
import csv
import math 

def read_data(filename):
    with open(filename, 'r') as csvfile:
        datareader = csv.reader(csvfile)
        metadata = next(datareader)
        traindata = [row for row in datareader]
    return metadata, traindata

def splitDataset(dataset, splitRatio):
    trainsize = int(len(dataset) * splitRatio)
    trainset = dataset[:trainsize]
    testset = dataset[trainsize:]
    return trainset, testset

def classify(data, test):
    tol_size = len(data)
    print("\n")
    print("training dataset size", tol_size)
    print("test size", len(test))
    
    # Calculate countno and countyes using only the training set
    countyes = sum(1 for row in data if row[-1] == 'yes')
    countno = sum(1 for row in data if row[-1] == 'no')
    
    probyes = countyes / tol_size
    probno = countno / tol_size
    print("\n")
    print("target cannot probability")
    print('yes', "\t", countyes, "\t", probyes)
    print('no', "\t", countno, "\t", probno)
    
    prob0 = np.zeros((len(test[0]) - 1))
    prob1 = np.zeros((len(test[0]) - 1))
    accuracy = 0
    print("\n")
    print("instance pridiction value")
    
    for t in range(len(test)):
        for k in range(len(test[0]) - 1):
            count1 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'yes')
            count0 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'no')
            prob0[k] = count0 / countno
            prob1[k] = count1 / countyes
        
        probno = countno / tol_size
        probyes = countyes / tol_size
        
        for i in range(len(test[0]) - 1):
            probno = probno * prob0[i]
            probyes = probyes * prob1[i]
        
        if probno > probyes:
            predict = 'no'
        else:
            predict = 'yes'
        
        print(t + 1, "\t", predict, "\t", test[t, -1])
        
        if predict == test[t, -1]:
            accuracy += 1
    
    final_accuracy = (accuracy / len(test)) * 100
    print("accuracy", final_accuracy, "%")

metadata, traindata = read_data("we.csv")
print("the attribute names of training data:", metadata)
splitRatio = 0.6
trainingset, testset = splitDataset(traindata, splitRatio)
training = np.array(trainingset)
print("\ntraining sets are")
for x in trainingset:
    print(x)
testing = np.array(testset)
print("\nthe datasets are")
for x in testing:
    print(x)
classify(training, testing)
# Out:
# the attribute names of training data: ['weather', 'temperature', 'humidity', 'wind']
#
# training sets are
# ['suuny', 'hot', 'high', 'weak']
#
# the datasets are
# ['suuny' 'hot' 'high' 'strong']
# ['cloudy' 'hot' 'high' 'weak']
#
#
# training dataset size 1
# test size 2
#
#
# target cannot probability
# yes 	 0 	 0.0
# no 	 0 	 0.0
#
#
# instance pridiction value
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 80
#      78 for x in testing:
#      79     print(x)
# ---> 80 classify(training, testing)
#
# Cell In[16], line 45, in classify(data, test)
#      43     count1 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'yes')
#      44     count0 = sum(1 for row in data if row[k] == test[t, k] and row[-1] == 'no')
# ---> 45     prob0[k] = count0 / countno
#      46     prob1[k] = count1 / countyes
#      48 probno = countno / tol_size
#
# ZeroDivisionError: division by zero
