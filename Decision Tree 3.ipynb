# %%
import pandas as pd
import numpy as np
import math
import csv

# %%
class Node:
    def __init__(self,attribute):
        self.attribute = attribute
        self.children = []
        self.answer = None

# %%
def read_data(filename):
    with open(filename,'r') as csvfile:
        datareader = csv.reader(csvfile,delimiter=',')
        header = next(datareader)
        traindata =[row for row in datareader]
    return headers,traindata

# %%
def read_data():
    with open(filename,'r') as csvfile:
        datareader = csv.reader(csvfile,delimiter=',')
        testdata = [row for row in datareader]
    return testdata

# %%
def subtables(dat,col,delete):
    dict = {}
    items = np.unique(data[:,col])
    for item in items:
        dict[item] = data[data[:,col]==item]
        if delete:
            dict[item] = np.delete(dict[item],col,axis=1)
        return items,dict

# %%
def entropy(S):
    items,counts = np.unique(S,return_counts = True)
    probablities =counts/len(S)
    return -np.sum(probablities *np.log2(probablities))

# %%
def gain_ratio(data,col):
    total_entropy =entropy(data[:,-1])
    items,dict =subtitles(data,col,delete=False)
    
    subset_entropy =0
    intrinisic_value =0
    total_size =data.shape[0]
    
    for item in items:
        subset = dict[item]
        ratio =len(subset)/total_size
        subset_entropy += ratio * entropy(subset[:,-1])
        intrinisic_value -= ratio *math.log(ratio,2)
    if intrinisic_value ==0:
         return 0
    information_gain = total_entropy - subset_entropy
    return information_gain / intrinisic_value

# %%
#building decision tree
def create_node(date,metadata):
    if len(np.unique(data[:,-1])) == 1:
        node = Node(None)
        node.answer=np.unique(data[:,-1]) [0]
        return node
    gains = [gain_ratio(data,col) for col in range(data.shape[1] -1)]
    split = np.argmax(gains)
    node = Node(metadata[split])
    items,dict = subtables(data,split,delete=True)
    
    for item in items:
        child = create_node(dict[item],np.delete(metadata,split))
        node.children.append((item,child))
        
    return node

# %%
# Making prediction
def predict(node,instance,metadata):
    if node.answer is not None:
        return node.answer
    value = instance[metadata.index(node.attribute)]
    for item ,child in node.children:
        if item == value :
            return predict(child,instance,metadata)

# %%
#utility function for printing
def empty(size):
    return "  " * size
def print_tree(node,level):
    if node.answer is not None:
        print(empty(level),node.answer)
        return
    print(empty(level),node.attribute)
    for value, n in node.children:
        print(empty(level + 1),value)
        print_tree(n,level + 2)

# %%
# print prediction
def print_predictions(node,testdata,metadata):
    test_instances = testdata[1:]
    for instance in test_instances:
        prediction = predict(node,instance,metadata)
        print(f"the test instance:{instance}")
        print( f"the predicted label:{predictions}\n")

# %%
metadata ,traindata =read_data("train.csv")
test_data = read_test_data("we.csv")
data = np.array(traindata)
node= create_node(data,metadata)

print("decision tree structure:")
print_tree(node,0)
print("\n prediction for test data:")
print_prediction(Node,test_data,metadata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 metadata ,traindata =read_data("train.csv")
#       2 test_data = read_test_data("we.csv")
#       3 data = np.array(traindata)
#
# TypeError: read_data() takes 0 positional arguments but 1 was given

# %%
import pandas as pd
import numpy as np
import math
import csv

class Node:
    def __init__(self, attribute):
        self.attribute = attribute
        self.children = []
        self.answer = None

def read_data(filename):
    with open(filename, 'r') as csvfile:
        datareader = csv.reader(csvfile, delimiter=',')
        header = next(datareader)
        traindata = [row for row in datareader]
    return header, traindata

def read_test_data(filename):
    with open(filename, 'r') as csvfile:
        datareader = csv.reader(csvfile, delimiter=',')
        testdata = [row for row in datareader]
    return testdata

def subtables(data, col, delete):
    dict = {}
    items = np.unique(data[:, col])
    for item in items:
        dict[item] = data[data[:, col] == item]
        if delete:
            dict[item] = np.delete(dict[item], col, axis=1)
    return items, dict

def entropy(S):
    items, counts = np.unique(S, return_counts=True)
    probabilities = counts / len(S)
    return -np.sum(probabilities * np.log2(probabilities))

def gain_ratio(data, col):
    total_entropy = entropy(data[:, -1])
    items, dict = subtables(data, col, delete=False)
    subset_entropy = 0
    intrinsic_value = 0
    total_size = data.shape[0]
    
    for item in items:
        subset = dict[item]
        ratio = len(subset) / total_size
        subset_entropy += ratio * entropy(subset[:, -1])
        intrinsic_value -= ratio * math.log(ratio, 2)
        
    if intrinsic_value == 0:
        return 0
    
    information_gain = total_entropy - subset_entropy
    return information_gain / intrinsic_value

def create_node(data, metadata):
    if len(np.unique(data[:, -1])) == 1:
        node = Node(None)
        node.answer = np.unique(data[:, -1])[0]
        return node
    
    gains = [gain_ratio(data, col) for col in range(data.shape[1] - 1)]
    split = np.argmax(gains)
    node = Node(metadata[split])
    items, dict = subtables(data, split, delete=True)
    
    for item in items:
        child = create_node(dict[item], np.delete(metadata, split))
        node.children.append((item, child))
        
    return node

def predict(node, instance, metadata):
    if node.answer is not None:
        return node.answer
    value = instance[metadata.index(node.attribute)]
    for item, child in node.children:
        if item == value:
            return predict(child, instance, metadata)

def print_tree(node, level):
    if node.answer is not None:
        print(empty(level), node.answer)
        return
    print(empty(level), node.attribute)
    for value, n in node.children:
        print(empty(level + 1), value)
        print_tree(n, level + 2)

def print_predictions(node, testdata, metadata):
    test_instances = testdata[1:]
    for instance in test_instances:
        prediction = predict(node, instance, metadata)
        print(f"The test instance: {instance}")
        print(f"The predicted label: {prediction}\n")

def empty(size):
    return "  " * size

metadata, traindata = read_data("train.csv")
test_data = read_test_data("we.csv")
data = np.array(traindata)
node = create_node(data, metadata)

print("Decision tree structure:")
print_tree(node, 0)
print("\nPrediction for test data:")
print_predictions(node, test_data, metadata)
# Out:
# Decision tree structure:
#  weather
#    cloudy
#      yes
#    rain
#      wind
#        strong
#          no
#        weak
#          yes
#    sunny
#      humidity
#        high
#          no
#        normal
#          yes
#
# Prediction for test data:
# The test instance: ['suuny', 'hot', 'high', 'weak']
# The predicted label: None
#
# The test instance: ['suuny', 'hot', 'high', 'strong']
# The predicted label: None
#
# The test instance: ['cloudy', 'hot', 'high', 'weak']
# The predicted label: yes
